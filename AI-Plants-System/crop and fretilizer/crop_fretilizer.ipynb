# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB

# %%
ds=pd.read_csv("Crop and fertilizer dataset.csv")

# %%
ds.head()
# Out:
#   District_Name Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  \
# 0      Kolhapur      Black        75          50        100  6.5      1000
# 1      Kolhapur      Black        80          50        100  6.5      1000
# 2      Kolhapur      Black        85          50        100  6.5      1000
# 3      Kolhapur      Black        90          50        100  6.5      1000
# 4      Kolhapur      Black        95          50        100  6.5      1000
#
#    Temperature       Crop Fertilizer                          Link
# 0           20  Sugarcane       Urea  https://youtu.be/2t5Am0xLTOo
# 1           20  Sugarcane       Urea  https://youtu.be/2t5Am0xLTOo
# 2           20  Sugarcane       Urea  https://youtu.be/2t5Am0xLTOo
# 3           20  Sugarcane       Urea  https://youtu.be/2t5Am0xLTOo
# 4           20  Sugarcane       Urea  https://youtu.be/2t5Am0xLTOo

# %%
ds.isnull().sum()
# Out:
# District_Name    0
# Soil_color       0
# Nitrogen         0
# Phosphorus       0
# Potassium        0
# pH               0
# Rainfall         0
# Temperature      0
# Crop             0
# Fertilizer       0
# Link             0
# dtype: int64

# %%
label_encoder = LabelEncoder()
ds["Soil_color"]=label_encoder.fit_transform(ds["Soil_color"])
ds["Crop"]=label_encoder.fit_transform(ds["Crop"])
ds["Fertilizer"]=label_encoder.fit_transform(ds["Fertilizer"])

# %%
ds.tail()
# Out:
#      District_Name  Soil_color  Nitrogen  Phosphorus  Potassium   pH  \
# 4508          Pune           0       130          80        150  7.0
# 4509          Pune           0       135          80        150  7.0
# 4510          Pune           0       140          80        150  7.0
# 4511          Pune           0       145          80        150  7.0
# 4512          Pune           0       150          80        150  7.0
#
#       Rainfall  Temperature  Crop  Fertilizer                          Link
# 4508      1400           30    11          13  https://youtu.be/2t5Am0xLTOo
# 4509      1400           30    11          13  https://youtu.be/2t5Am0xLTOo
# 4510      1400           30    11          13  https://youtu.be/2t5Am0xLTOo
# 4511      1400           30    11          13  https://youtu.be/2t5Am0xLTOo
# 4512      1400           30    11          13  https://youtu.be/2t5Am0xLTOo

# %%
ds["Soil_color"].value_counts()
# Out:
# Soil_color
# 0    2260
# 4     744
# 1     659
# 5     480
# 6     265
# 2      54
# 3      51
# Name: count, dtype: int64

# %%
x=ds.drop(columns=['District_Name', 'Link', 'Fertilizer'])
y=ds["Fertilizer"]
x
# Out:
#       Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  Temperature  \
# 0              0        75          50        100  6.5      1000           20
# 1              0        80          50        100  6.5      1000           20
# 2              0        85          50        100  6.5      1000           20
# 3              0        90          50        100  6.5      1000           20
# 4              0        95          50        100  6.5      1000           20
# ...          ...       ...         ...        ...  ...       ...          ...
# 4508           0       130          80        150  7.0      1400           30
# 4509           0       135          80        150  7.0      1400           30
# 4510           0       140          80        150  7.0      1400           30
# 4511           0       145          80        150  7.0      1400           30
# 4512           0       150          80        150  7.0      1400           30
#
#       Crop
# 0       11
# ...

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# models=[LogisticRegression(), SVC(kernel='linear'), GaussianNB(), RandomForestClassifier(), DecisionTreeClassifier(), KNeighborsClassifier()]

# for model in models:
#     model.fit(x_train, y_train)
#     x_train_predication=model.predict(x_train)
#     training_accuracy=accuracy_score(x_train_predication, y_train)
#     print(model.__class__.__name__)
#     print(training_accuracy)
#     print("------------------------")

# %%
model=DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
input_data=(0,75,50,100,6.5,1000,20,11,0,11)
#changing the input data to numpy array
input_data_as_numpy_array=np.array(input_data)
#reshape the array
input_data_reshaped=input_data_as_numpy_array.reshape(1, -1)

prediction=model.predict(input_data_reshaped)
print(prediction)
# Out:
# c:\Users\jk\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 7
#       4 #reshape the array
#       5 input_data_reshaped=input_data_as_numpy_array.reshape(1, -1)
# ----> 7 prediction=model.predict(input_data_reshaped)
#       8 print(prediction)
#
# File c:\Users\jk\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
# ...

# %%
# le = LabelEncoder()

# Encode the category column
#ds['category_encoded'] = le.fit_transform(ds['category'])

# print("Original Categories:")
# print(ds['Crop'].value_counts())

print("\nEncoded Categories:")
print(ds['Crop_new'].value_counts())

# print("\nDetailed Mapping:")
# for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
#     print(f"Original: {original}, Encoded: {encoded}")
# Out:
# Encoded Categories:
# Crop_new
# 11    1010
# 15     859
# 0      650
# 5      394
# 6      350
# 9      309
# 4      177
# 12     126
# 3      125
# 1      125
# 14      99
# 8       99
# 2       78
# 13      55
# 10      45
# 7       12
# Name: count, dtype: int64

# %%
import pickle
import numpy as np

model = pickle.load(open('fertilizer_type_model.pkl', 'rb'))

input_data=(0,150,80,150,7.0,1400,30,11)
#changing the input data to numpy array
input_data_as_numpy_array=np.array(input_data)
#reshape the arraay
input_data_reshaped=input_data_as_numpy_array.reshape(1, -1)

prediction=model.predict(input_data_reshaped)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 12
#       9 #reshape the array
#      10 input_data_reshaped=input_data_as_numpy_array.reshape(1, -1)
# ---> 12 prediction=model.predict(input_data_reshaped)
#      13 print(prediction)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'predict'
